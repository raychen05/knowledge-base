# %% [markdown]
# #### 1. ACS Schema, Table  Defintition

# %%
// ACS Table trait with logical table names
sealed trait ACS {
  def tableName: String
  def tableType: String
  def description: String
  def fullName: String = AcsResolver.getName(this)
  // Make ACS.<object> auto-return full name
  override def toString: String = fullName
}

object ACS {
 
  // gold_entity tables
    case object DAlmaOpenAccess extends ACS { val tableName = "d_alma_openaccess"; val tableType = "entity"; val description = "Alma Open Access Data" }
    case object DAlmaSubscriptions extends ACS { val tableName = "d_alma_subscriptions"; val tableType = "entity"; val description = "Alma Subscriptions Data" }
    case object DEsiAuthor extends ACS { val tableName = "d_esi_author"; val tableType = "entity"; val description = "ESI Author Data" }
    case object DEsiCountry extends ACS { val tableName = "d_esi_country"; val tableType = "entity"; val description = "ESI Country Data" }
    case object DEsiInstitution extends ACS { val tableName = "d_esi_institution"; val tableType = "entity"; val description = "ESI Institution Data" }
    case object DEsiJournal extends ACS { val tableName = "d_esi_journal"; val tableType = "entity"; val description = "ESI Journal Data" }
    case object DFundingOrganization extends ACS { val tableName = "d_funding_organization"; val tableType = "entity"; val description = "Funding Organization Data" }
    case object DGrantmasterDataitem extends ACS { val tableName = "d_grantmaster_dataitem"; val tableType = "entity"; val description = "Grantmaster Data Item" }
    case object DGrantmasterGrantid extends ACS { val tableName = "d_grantmaster_grantid"; val tableType = "entity"; val description = "Grantmaster Grant ID" }
    case object DJcrJournals extends ACS { val tableName = "d_jcr_journals"; val tableType = "entity"; val description = "JCR Journals Data" }
    case object DNuts extends ACS { val tableName = "d_nuts"; val tableType = "entity"; val description = "NUTS Data" }
    case object DNutsCode extends ACS { val tableName = "d_nuts_code"; val tableType = "entity"; val description = "NUTS Code Data" }
    case object DOrcidRid extends ACS { val tableName = "d_orcid_rid"; val tableType = "entity"; val description = "ORCID RID Data" }
    case object DOrgmaster extends ACS { val tableName = "d_orgmaster"; val tableType = "entity"; val description = "Organization Master Data" }
    case object DOrgmasterAssociation extends ACS { val tableName = "d_orgmaster_association"; val tableType = "entity"; val description = "Organization Master Association Data" }
    case object DParentChild extends ACS { val tableName = "d_parent_child"; val tableType = "entity"; val description = "Parent Child Relationship Data" }
    case object DSpmaster extends ACS { val tableName = "d_spmaster"; val tableType = "entity"; val description = "SP Master Data" }
    case object FIpInstitution extends ACS { val tableName = "f_ip_institution"; val tableType = "entity"; val description = "IP Institution Fact Data" }
    case object FIpInstitutionReputation extends ACS { val tableName = "f_ip_institution_reputation"; val tableType = "entity"; val description = "IP Institution Reputation Fact Data" }
    case object FJcrJournal extends ACS { val tableName = "f_jcr_journal"; val tableType = "entity"; val description = "JCR Journal Fact Data" }
    case object FJcrJournalCategory extends ACS { val tableName = "f_jcr_journal_category"; val tableType = "entity"; val description = "JCR Journal Category Fact Data" }
    case object FJcrJournalJci extends ACS { val tableName = "f_jcr_journal_jci"; val tableType = "entity"; val description = "JCR Journal JCI Fact Data" }
    case object FundingOrgPublicationLink extends ACS { val tableName = "funding_org_publication_link"; val tableType = "entity"; val description = "Funding Organization Publication Link" }
    case object GrantmasterOrgmasterLink extends ACS { val tableName = "grantmaster_orgmaster_link"; val tableType = "entity"; val description = "Grantmaster Organization Master Link" }
    case object GrantmasterPublicationLink extends ACS { val tableName = "grantmaster_publication_link"; val tableType = "entity"; val description = "Grantmaster Publication Link" }
    case object JournalPublisherLink extends ACS { val tableName = "journal_publisher_link"; val tableType = "entity"; val description = "Journal Publisher Link" }
    case object OrcidRidPublicationLink extends ACS { val tableName = "orcid_rid_publication_link"; val tableType = "entity"; val description = "ORCID RID Publication Link" }
    case object OrgmasterHeirarchyPublicationLink extends ACS { val tableName = "orgmaster_heirarchy_publication_link"; val tableType = "entity"; val description = "Organization Master Heirarchy Publication Link" }
    case object OrgmasterHierarchyPublicationLink extends ACS { val tableName = "orgmaster_hierarchy_publication_link"; val tableType = "entity"; val description = "Organization Master Hierarchy Publication Link" }
    case object OrgmasterPublicationLink extends ACS { val tableName = "orgmaster_publication_link"; val tableType = "entity"; val description = "Organization Master Publication Link" }
    case object SpmasterPublicationLink extends ACS { val tableName = "spmaster_publication_link"; val tableType = "entity"; val description = "SP Master Publication Link" }


    // gold_wos / gold_pprn tables
    case object AddressPublicationLink extends ACS { val tableName = "address_publication_link"; val tableType = "collection"; val description = "Address Publication Link" }
    case object AuthorPublicationLink extends ACS { val tableName = "author_publication_link"; val tableType = "collection"; val description = "Author Publication Link" }
    case object CategoryPublicationLink extends ACS { val tableName = "category_publication_link"; val tableType = "collection"; val description = "Category Publication Link" }
    case object CountryPublicationLink extends ACS { val tableName = "country_publication_link"; val tableType = "collection"; val description = "Country Publication Link" }
    case object CountryTerritoryLink extends ACS { val tableName = "country_territory_link"; val tableType = "collection"; val description = "Country Territory Link" }
    case object DAlcCompleteLabels extends ACS { val tableName = "d_alc_complete_labels"; val tableType = "collection"; val description = "ALC Complete Labels Data" }
    case object DArticleFlag extends ACS { val tableName = "d_article_flag"; val tableType = "dataset"; val description = "Article Flag Data" }
    case object DArticleFlagWoscore extends ACS { val tableName = "d_article_flag_woscore"; val tableType = "collection"; val description = "Article Flag WOS Core Data" }
    case object DArticleIdentifiers extends ACS { val tableName = "d_article_identifiers"; val tableType = "collection"; val description = "Article Identifiers Data" }
    case object DArticleMetrics extends ACS { val tableName = "d_article_metrics"; val tableType = "dataset"; val description = "Article Metrics Data" }
    case object DArticleMetricsWoscore extends ACS { val tableName = "d_article_metrics_woscore"; val tableType = "collection"; val description = "Article Metrics WOS Core Data" }
    case object DArticleTotalCites extends ACS { val tableName = "d_article_total_cites"; val tableType = "dataset"; val description = "Article Total Citations Data" }
    case object DArticleTotalCitesWoscore extends ACS { val tableName = "d_article_total_cites_woscore"; val tableType = "collection"; val description = "Article Total Citations WOS Core Data" }
    case object DArticleType extends ACS { val tableName = "d_article_type"; val tableType = "collection"; val description = "Article Type Data" }
    case object DArticleTypePrecedence extends ACS { val tableName = "d_article_type_precedence"; val tableType = "collection"; val description = "Article Type Precedence Data" }
    case object DAuthor extends ACS { val tableName = "d_author"; val tableType = "collection"; val description = "Author Data" }
    case object DCategory extends ACS { val tableName = "d_category"; val tableType = "collection"; val description = "Category Data" }
    case object DCitation extends ACS { val tableName = "d_citation"; val tableType = "collection"; val description = "Citation Data" }
    case object DCitationFlag extends ACS { val tableName = "d_citation_flag"; val tableType = "collection"; val description = "Citation Flag Data" }
    case object DCitationPatent extends ACS { val tableName = "d_citation_patent"; val tableType = "dataset"; val description = "Citation Patent Data" }
    case object DCitationPatentWoscore extends ACS { val tableName = "d_citation_patent_woscore"; val tableType = "collection"; val description = "Citation Patent WOS Core Data" }
    case object DCitationPatentFlag extends ACS { val tableName = "d_citation_patent_flag"; val tableType = "dataset"; val description = "Citation Patent Flag Data" }
    case object DCitationPatentsFlag extends ACS { val tableName = "d_citation_patents_flag"; val tableType = "collection"; val description = "Citation Patents Flag Data" }
    case object DCountry extends ACS { val tableName = "d_country"; val tableType = "collection"; val description = "Country Data" }
    case object DDaisngRankedAffiliation extends ACS { val tableName = "d_daisng_ranked_affiliation"; val tableType = "dataset"; val description = "DAISNG Ranked Affiliation Data" }
    case object DDaisngRankedAffiliationWoscore extends ACS { val tableName = "d_daisng_ranked_affiliation_woscore"; val tableType = "collection"; val description = "DAISNG Ranked Affiliation WOS Core Data" }
    case object DDomesticCollab extends ACS { val tableName = "d_domestic_collab"; val tableType = "collection"; val description = "Domestic Collaboration Data" }
    case object DDomesticInternationalCollab extends ACS { val tableName = "d_domestic_international_collab"; val tableType = "dataset"; val description = "Domestic International Collaboration Data" }
    case object DDomesticInternationalCollabWoscore extends ACS { val tableName = "d_domestic_international_collab_woscore"; val tableType = "collection"; val description = "Domestic International Collaboration WOS Core Data" }
    case object DDomesticInternationalCollabtype extends ACS { val tableName = "d_domestic_international_collabtype"; val tableType = "collection"; val description = "Domestic International Collaboration Type Data" }
    case object DEdition extends ACS { val tableName = "d_edition"; val tableType = "collection"; val description = "Edition Data" }
    case object DEmtCompleteLabels extends ACS { val tableName = "d_emt_complete_labels"; val tableType = "collection"; val description = "EMT Complete Labels Data" }
    case object DGrantDataitem extends ACS { val tableName = "d_grant_dataitem"; val tableType = "collection"; val description = "Grant Data Item" }
    case object DJournal extends ACS { val tableName = "d_journal"; val tableType = "collection"; val description = "Journal Data" }
    case object DJournalAcs extends ACS { val tableName = "d_journal_acs"; val tableType = "collection"; val description = "Journal ACS Data" }
    case object DJournalPublisher extends ACS { val tableName = "d_journal_publisher"; val tableType = "collection"; val description = "Journal Publisher Data" }
    case object DLocation extends ACS { val tableName = "d_location"; val tableType = "collection"; val description = "Location Data" }
    case object DOaArticle extends ACS { val tableName = "d_oa_article"; val tableType = "collection"; val description = "Open Access Article Data" }
    case object DOrganization extends ACS { val tableName = "d_organization"; val tableType = "collection"; val description = "Organization Data" }
    case object DOrganizationCitationCount extends ACS { val tableName = "d_organization_citation_count"; val tableType = "dataset"; val description = "Organization Citation Count Data" }
    case object DOrganizationCitationCountWoscore extends ACS { val tableName = "d_organization_citation_count_woscore"; val tableType = "collection"; val description = "Organization Citation Count WOS Core Data" }
    case object DOrganizationCitationFlag extends ACS { val tableName = "d_organization_citation_flag"; val tableType = "collection"; val description = "Organization Citation Flag Data" }
    case object DPublicationSourceCitationCount extends ACS { val tableName = "d_publication_source_citation_count"; val tableType = "dataset"; val description = "Publication Source Citation Count Data" }
    case object DPublicationSourceCitationCountWoscore extends ACS { val tableName = "d_publication_source_citation_count_woscore"; val tableType = "collection"; val description = "Publication Source Citation Count WOS Core Data" }
    case object DPublicationSourceCitationFlag extends ACS { val tableName = "d_publication_source_citation_flag"; val tableType = "collection"; val description = "Publication Source Citation Flag Data" }
    case object DPublisher extends ACS { val tableName = "d_publisher"; val tableType = "collection"; val description = "Publisher Data" }
    case object DResearcherCitationCount extends ACS { val tableName = "d_researcher_citation_count"; val tableType = "dataset"; val description = "Researcher Citation Count Data" }
    case object DResearcherCitationCountWoscore extends ACS { val tableName = "d_researcher_citation_count_woscore"; val tableType = "collection"; val description = "Researcher Citation Count WOS Core Data" }
    case object DResearcherCitationsFlag extends ACS { val tableName = "d_researcher_citations_flag"; val tableType = "collection"; val description = "Researcher Citations Flag Data" }
    case object DState extends ACS { val tableName = "d_state"; val tableType = "collection"; val description = "State Data" }
    case object DTerritory extends ACS { val tableName = "d_territory"; val tableType = "collection"; val description = "Territory Data" }
    case object DYearwiseCitation extends ACS { val tableName = "d_yearwise_citation"; val tableType = "dataset"; val description = "Yearwise Citation Data" }
    case object DYearwiseCitationWoscore extends ACS { val tableName = "d_yearwise_citation_woscore"; val tableType = "collection"; val description = "Yearwise Citation WOS Core Data" }
    case object DYearwiseCitationCount extends ACS { val tableName = "d_yearwise_citation_count"; val tableType = "dataset"; val description = "Yearwise Citation Count Data" }
    case object DYearwiseCitationCountWoscore extends ACS { val tableName = "d_yearwise_citation_count_woscore"; val tableType = "collection"; val description = "Yearwise Citation Count WOS Core Data" }
    case object FArticleCountry extends ACS { val tableName = "f_article_country"; val tableType = "dataset"; val description = "Article Country Fact Data" }
    case object FArticleCountryWoscore extends ACS { val tableName = "f_article_country_woscore"; val tableType = "collection"; val description = "Article Country WOS Core Fact Data" }
    case object FCategory extends ACS { val tableName = "f_category"; val tableType = "dataset"; val description = "Category Fact Data" }
    case object FCategoryWoscore extends ACS { val tableName = "f_category_woscore"; val tableType = "collection"; val description = "Category WOS Core Fact Data" }
    case object FCountry extends ACS { val tableName = "f_country"; val tableType = "dataset"; val description = "Country Fact Data" }
    case object FCountryWoscore extends ACS { val tableName = "f_country_woscore"; val tableType = "collection"; val description = "Country WOS Core Fact Data" }
    case object FPublication extends ACS { val tableName = "f_publication"; val tableType = "collection"; val description = "Publication Fact Data" }
    case object GrantFundingOrganizationLink extends ACS { val tableName = "grant_funding_organization_link"; val tableType = "collection"; val description = "Grant Funding Organization Link" }
    case object JournalAcsPublicationLink extends ACS { val tableName = "journal_acs_publication_link"; val tableType = "collection"; val description = "Journal ACS Publication Link" }
    case object JournalPublicationLink extends ACS { val tableName = "journal_publication_link"; val tableType = "collection"; val description = "Journal Publication Link" }
    case object NutsPublicationLink extends ACS { val tableName = "nuts_publication_link"; val tableType = "collection"; val description = "NUTS Publication Link" }
    case object PublisherPublicationLink extends ACS { val tableName = "publisher_publication_link"; val tableType = "collection"; val description = "Publisher Publication Link" }
    case object ReprintAddressPublicationLink extends ACS { val tableName = "reprint_address_publication_link"; val tableType = "collection"; val description = "Reprint Address Publication Link" }
    case object StatePublicationLink extends ACS { val tableName = "state_publication_link"; val tableType = "collection"; val description = "State Publication Link" }
    case object TerritoryPublicationLink extends ACS { val tableName = "territory_publication_link"; val tableType = "collection"; val description = "Territory Publication Link" }

}

object AcsResolver {
  private def getWidget(name: String, default: String): String = {
    try {
      val value = dbutils.widgets.get(name)
      if (value == null || value.isEmpty) default else value
    } catch {
      case _: Throwable => default
    }
  }

  private val environment = getWidget("environment", "dev")
  private val version = getWidget("version", "v1_0")
  private val collection = getWidget("collection", "wos") // wos, pprn
  // private val dataset = getWidget("dataset", "woscore")
  private val catalog = s"ag_ra_search_analytics_data_${environment}"
  private var dataset = "" 

  def setDataset(dataSet: String = ""): Unit ={
      dataset = if (dataSet == "woscore") "_woscore" else ""
  }

  def getName(table: ACS): String = {
    table.tableType match {
      case "entity"     => s"${catalog}.gold_entity_${version}.${table.tableName}"
      case "collection" => s"${catalog}.gold_${collection}_${version}.${table.tableName}"
      case "dataset"    => s"${catalog}.gold_${collection}_${version}.${table.tableName}${dataset}"
    }
  }
}

# %% [markdown]
# #### 2. ACS Test

# %%
// Test Example
object AcsTestApp extends App {

  println(AcsResolver.getName(ACS.AddressPublicationLink))
  println(AcsResolver.getName(ACS.DFundingOrganization))

  println("--------")

  println(ACS.DFundingOrganization.fullName)
  println(ACS.AddressPublicationLink.fullName)
  println(ACS.DEsiAuthor.fullName) 
  println(ACS.JournalAcsPublicationLink.fullName)


  println("--------")
  AcsResolver.dataset("woscore")
  println(ACS.DCitationPatent.fullName)
  println(ACS.DCitationPatentWoscore.fullName)

  println("--------")
  AcsResolver.dataset("esci")
  println(ACS.FArticleCountry.fullName)
  println(ACS.FArticleCountryWoscore.fullName)
  println(ACS.JournalPublisherLink.fullName)

}
