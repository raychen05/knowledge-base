// %% [markdown]
// #### 1. ACS Enum Definition

// %%
// Table enum with logical table names
enum Table(val tableName: String, val tableType: String):

  // gold_entity tables
  case object DAlmaOpenAccess extends Table("d_alma_openaccess", "entity")
  case object DAlmaSubscriptions extends Table("d_alma_subscriptions", "entity")
  case object DEsiAuthor extends Table("d_esi_author", "entity")
  case object DEsiCountry extends Table("d_esi_country", "entity")
  case object DEsiInstitution extends Table("d_esi_institution", "entity")
  case object DEsiJournal extends Table("d_esi_journal", "entity")
  case object DFundingOrganization extends Table("d_funding_organization", "entity")
  case object DGrantmasterDataitem extends Table("d_grantmaster_dataitem", "entity")
  case object DGrantmasterGrantid extends Table("d_grantmaster_grantid", "entity")
  case object DJcrJournals extends Table("d_jcr_journals", "entity")
  case object DNuts extends Table("d_nuts", "entity")
  case object DNutsCode extends Table("d_nuts_code", "entity")
  case object DOrcidRid extends Table("d_orcid_rid", "entity")
  case object DOrgmaster extends Table("d_orgmaster", "entity")
  case object DOrgmasterAssociation extends Table("d_orgmaster_association", "entity")
  case object DParentChild extends Table("d_parent_child", "entity")
  case object DSpmaster extends Table("d_spmaster", "entity")
  case object FIpInstitution extends Table("f_ip_institution", "entity")
  case object FIpInstitutionReputation extends Table("f_ip_institution_reputation", "entity")
  case object FJcrJournal extends Table("f_jcr_journal", "entity")
  case object FJcrJournalCategory extends Table("f_jcr_journal_category", "entity")
  case object FJcrJournalJci extends Table("f_jcr_journal_jci", "entity")
  case object FundingOrgPublicationLink extends Table("funding_org_publication_link", "entity")
  case object GrantmasterOrgmasterLink extends Table("grantmaster_orgmaster_link", "entity")
  case object GrantmasterPublicationLink extends Table("grantmaster_publication_link", "entity")
  case object JournalPublisherLink extends Table("journal_publisher_link", "entity")
  case object OrcidRidPublicationLink extends Table("orcid_rid_publication_link", "entity")
  case object OrgmasterHeirarchyPublicationLink extends Table("orgmaster_heirarchy_publication_link", "entity")
  case object OrgmasterHierarchyPublicationLink extends Table("orgmaster_hierarchy_publication_link", "entity")
  case object OrgmasterPublicationLink extends Table("orgmaster_publication_link", "entity")
  case object SpmasterPublicationLink extends Table("spmaster_publication_link", "entity")

  // gold_wos / gold_pprn tables
  case object AddressPublicationLink extends Table("address_publication_link", "collection")
  case object AuthorPublicationLink extends Table("author_publication_link", "collection")
  case object CategoryPublicationLink extends Table("category_publication_link", "collection")
  case object CountryPublicationLink extends Table("country_publication_link", "collection")
  case object CountryTerritoryLink extends Table("country_territory_link", "collection")
  case object DAlcCompleteLabels extends Table("d_alc_complete_labels", "collection")
  case object DArticleFlag extends Table("d_article_flag", "collection")
  case object DArticleFlagWoscore extends Table("d_article_flag_woscore", "collection")
  case object DArticleIdentifiers extends Table("d_article_identifiers", "collection")
  case object DArticleMetrics extends Table("d_article_metrics", "collection")
  case object DArticleMetricsWoscore extends Table("d_article_metrics_woscore", "collection")
  case object DArticleTotalCites extends Table("d_article_total_cites", "collection")
  case object DArticleTotalCitesWoscore extends Table("d_article_total_cites_woscore", "collection")
  case object DArticleType extends Table("d_article_type", "collection")
  case object DArticleTypePrecedence extends Table("d_article_type_precedence", "collection")
  case object DAuthor extends Table("d_author", "collection")
  case object DCategory extends Table("d_category", "collection")
  case object DCitation extends Table("d_citation", "collection")
  case object DCitationFlag extends Table("d_citation_flag", "collection")
  case object DCitationPatent extends Table("d_citation_patent", "collection")
  case object DCitationPatentFlag extends Table("d_citation_patent_flag", "collection")
  case object DCitationPatentWoscore extends Table("d_citation_patent_woscore", "collection")
  case object DCitationPatentsFlag extends Table("d_citation_patents_flag", "collection")
  case object DCountry extends Table("d_country", "collection")
  case object DDaisngRankedAffiliation extends Table("d_daisng_ranked_affiliation", "collection")
  case object DDaisngRankedAffiliationWoscore extends Table("d_daisng_ranked_affiliation_woscore", "collection")
  case object DDomesticCollab extends Table("d_domestic_collab", "collection")
  case object DDomesticInternationalCollab extends Table("d_domestic_international_collab", "collection")
  case object DDomesticInternationalCollabWoscore extends Table("d_domestic_international_collab_woscore", "collection")
  case object DDomesticInternationalCollabtype extends Table("d_domestic_international_collabtype", "collection")
  case object DEdition extends Table("d_edition", "collection")
  case object DEmtCompleteLabels extends Table("d_emt_complete_labels", "collection")
  case object DEsciCitations extends Table("d_esci_citations", "collection")
  case object DEsciYearwiseCitations extends Table("d_esci_yearwise_citations", "collection")
  case object DGrantDataitem extends Table("d_grant_dataitem", "collection")
  case object DJournal extends Table("d_journal", "collection")
  case object DJournalAcs extends Table("d_journal_acs", "collection")
  case object DJournalPublisher extends Table("d_journal_publisher", "collection")
  case object DLocation extends Table("d_location", "collection")
  case object DNonEsciCitations extends Table("d_non_esci_citations", "collection")
  case object DNonEsciYearwiseCitations extends Table("d_non_esci_yearwise_citations", "collection")
  case object DOaArticle extends Table("d_oa_article", "collection")
  case object DOrganization extends Table("d_organization", "collection")
  case object DOrganizationCitationCount extends Table("d_organization_citation_count", "collection")
  case object DOrganizationCitationCountWoscore extends Table("d_organization_citation_count_woscore", "collection")
  case object DOrganizationCitationFlag extends Table("d_organization_citation_flag", "collection")
  case object DPublicationSourceCitationCount extends Table("d_publication_source_citation_count", "collection")
  case object DPublicationSourceCitationCountWoscore extends Table("d_publication_source_citation_count_woscore", "collection")
  case object DPublicationSourceCitationFlag extends Table("d_publication_source_citation_flag", "collection")
  case object DPublisher extends Table("d_publisher", "collection")
  case object DResearcherCitationCount extends Table("d_researcher_citation_count", "collection")
  case object DResearcherCitationCountWoscore extends Table("d_researcher_citation_count_woscore", "collection")
  case object DResearcherCitationsFlag extends Table("d_researcher_citations_flag", "collection")
  case object DState extends Table("d_state", "collection")
  case object DTerritory extends Table("d_territory", "collection")
  case object DYearwiseCitation extends Table("d_yearwise_citation", "collection")
  case object DYearwiseCitationCount extends Table("d_yearwise_citation_count", "collection")
  case object DYearwiseCitationCountWoscore extends Table("d_yearwise_citation_count_woscore", "collection")
  case object DYearwiseCitationWoscore extends Table("d_yearwise_citation_woscore", "collection")
  case object FArticleCountry extends Table("f_article_country", "collection")
  case object FArticleCountryWoscore extends Table("f_article_country_woscore", "collection")
  case object FCategory extends Table("f_category", "collection")
  case object FCategoryWoscore extends Table("f_category_woscore", "collection")
  case object FCountry extends Table("f_country", "collection")
  case object FCountryWoscore extends Table("f_country_woscore", "collection")
  case object FEsciCountry extends Table("f_esci_country", "collection")
  case object FNonEsciCountry extends Table("f_non_esci_country", "collection")
  case object FPublication extends Table("f_publication", "collection")
  case object GrantFundingOrganizationLink extends Table("grant_funding_organization_link", "collection")
  case object JournalAcsPublicationLink extends Table("journal_acs_publication_link", "collection")
  case object JournalPublicationLink extends Table("journal_publication_link", "collection")
  case object NutsPublicationLink extends Table("nuts_publication_link", "collection")
  case object PublisherPublicationLink extends Table("publisher_publication_link", "collection")
  case object ReprintAddressPublicationLink extends Table("reprint_address_publication_link", "collection")
  case object StatePublicationLink extends Table("state_publication_link", "collection")
  case object TerritoryPublicationLink extends Table("territory_publication_link", "collection")

  // Lazy vals to get environment, version and collection from dbutils (Databricks widgets)
  private lazy val environment = dbutils.widgets.get("environment", "dev")    // prod, dev, etc
  private lazy val version: String = dbutils.widgets.get("version", "v1_0")
  private lazy val collection: String = dbutils.widgets.get("collection", "wos")
  private lazy val catalog = s"ag_ra_search_analytics_data_${environment}"

  // Method to get full table name automatically
  def fullName: String = tableType match {
    case "entity"     => s"${catalog}.gold_entity_$version.$tableName"
    case "collection" => s"${catalog}.gold_${collection}_$version.$tableName"
  }



object TableResolver{

  // These would come from your Databricks config
  private val environment = dbutils.widgets.get("environment", "dev")    // prod, dev, etc
  private val version = dbutils.widgets.get("version", "v1_0")            // v1_0, v2_0, etc
  private val collection = dbutils.widgets.get("collection", "wos")      // wos, pprn

  private val catalog = s"ag_ra_search_analytics_data_${environment}"

  def getName(table: Table): String = {
    table.tableType match {
      case "entity"     => s"${catalog}.gold_entity_${version}.${table.tableName}"
      case "collection" => s"${catalog}.gold_${collection}_${version}.${table.tableName}"
    }
  }
}

// %% [markdown]
// #### 2. ACS Enum Test

// %%
object EnumTestApp extends App {
  // Example usage
  val table = Table.DAlmaOpenAccess
  println(s"Logical Name: ${table.tableName}")
  println(s"Full Table Name: ${table.fullName}")

  // Using TableResolver
  val fullNameFromResolver = TableResolver.getName(table)
  println(s"Full Table Name from Resolver: $fullNameFromResolver")
}
